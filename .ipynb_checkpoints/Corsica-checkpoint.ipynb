# %%
import pandas as pd

# %%
url = 'https://www.corsicahockey.com/nhl/players/nhl-player-ratings-rankings'

# %%
tables = pd.read_html(url)
tables
# Out:
# [              Player                 Team Position  Rating  Ranking  GP  Age  \
#  0     Leon Draisaitl      Edmonton Oilers        C   86.08        1  56   25
#  1   Nathan MacKinnon   Colorado Avalanche        C   84.15        2  48   25
#  2     Mika Zibanejad     New York Rangers        C   84.12        3  56   28
#  3     David Pastrnak        Boston Bruins       LW   83.84        1  48   25
#  4     Steven Stamkos  Tampa Bay Lightning        C   82.74        4  38   31
#  ..               ...                  ...      ...     ...      ...  ..  ...
#  95     Ryan O'Reilly       St Louis Blues        C   75.78       28  56   30
#  96    Jakob Chychrun      Arizona Coyotes       LD   75.73       13  56   23
#  97    Nikolaj Ehlers        Winnipeg Jets       LW   75.72       20  47   25
#  98      Antti Raanta      Arizona Coyotes        G   75.68        2  12   32
#  99        Jamie Benn         Dallas Stars       LW   75.55       21  52   31
#
#     Shoots              Opponent
# ...

# %%
 type(tables)
# Out:
# list

# %%
df = tables[0]
df.head()
# Out:
#              Player                 Team Position  Rating  Ranking  GP  Age  \
# 0    Leon Draisaitl      Edmonton Oilers        C   86.08        1  56   25
# 1  Nathan MacKinnon   Colorado Avalanche        C   84.15        2  48   25
# 2    Mika Zibanejad     New York Rangers        C   84.12        3  56   28
# 3    David Pastrnak        Boston Bruins       LW   83.84        1  48   25
# 4    Steven Stamkos  Tampa Bay Lightning        C   82.74        4  38   31
#
#   Shoots              Opponent
# 0      L                   NaN
# 1      R  Vegas Golden Knights
# 2      R                   NaN
# 3      R    New York Islanders
# 4      R                   NaN

# %%
df.fillna('-')
# Out:
#               Player                 Team Position  Rating  Ranking  GP  Age  \
# 0     Leon Draisaitl      Edmonton Oilers        C   86.08        1  56   25
# 1   Nathan MacKinnon   Colorado Avalanche        C   84.15        2  48   25
# 2     Mika Zibanejad     New York Rangers        C   84.12        3  56   28
# 3     David Pastrnak        Boston Bruins       LW   83.84        1  48   25
# 4     Steven Stamkos  Tampa Bay Lightning        C   82.74        4  38   31
# ..               ...                  ...      ...     ...      ...  ..  ...
# 95     Ryan O'Reilly       St Louis Blues        C   75.78       28  56   30
# 96    Jakob Chychrun      Arizona Coyotes       LD   75.73       13  56   23
# 97    Nikolaj Ehlers        Winnipeg Jets       LW   75.72       20  47   25
# 98      Antti Raanta      Arizona Coyotes        G   75.68        2  12   32
# 99        Jamie Benn         Dallas Stars       LW   75.55       21  52   31
#
#    Shoots              Opponent
# ...
